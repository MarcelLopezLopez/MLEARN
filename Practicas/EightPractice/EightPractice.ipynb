# %% [markdown]
# # Practice 8
# ## Objectives:
# 1. Understand the use of Gradient Boosting.
# 2. Understand the use of crossvalidation
# 3. Criterion for exploring the space of parameters
# 4. Be able to predict the mortality  (Total age-adjusted mortality rate per 100) and make a ranking of the data.
# taken from: http://lib.stat.cmu.edu/datasets/pollution
#
# ## Explanation of the database
# ### Note the heterogeniety of the input variables.
# This is the pollution data so loved by writers of papers on ridge regression.
# Source: McDonald, G.C. and Schwing, R.C. (1973) 'Instabilities of regression
# estimates relating air pollution to mortality', Technometrics, vol.15, 463-
# 482.
#
# Variables in order:
# * PREC   Average annual precipitation in inches
# * JANT   Average January temperature in degrees F
# * JULT   Same for July
# * OVR65  % of 1960 SMSA population aged 65 or older
# * POPN   Average household size
# * EDUC   Median school years completed by those over 22
# * HOUS   % of housing units which are sound & with all facilities
# * DENS   Population per sq. mile in urbanized areas
# * NONW   % non-white population in urbanized areas
# * WWDRK  % employed in white collar occupations
# * POOR   % of families with income < $3000
# * HC     Relative hydrocarbon pollution potential
# * NOX    Same for nitric oxides
# * SO@    Same for sulphur dioxide
# * HUMID  Annual average \% relative humidity at 1pm
# * MORT   Total age-adjusted mortality rate per 100

# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

# %%
File = "pollution.txt"
Filename = os.path.join(os.getcwd(),'Data',File)
print(f'Filename with path: \n {Filename}')
Data = pd.read_csv(Filename,  index_col=None,delimiter=r"\s+")
print(f'_'*50)
print(f'Shape of the database:{Data.shape}')
Data.head()
# Out:
# Filename with path:
#  c:\Users\Marcel\Uni\Master\MLEARN\MLEARN\Practicas\EightPractice\Data\pollution.txt
# __________________________________________________
# Shape of the database:(60, 16)
#    x1  x2  x3    x4    x5    x6    x7    x8    x9   x10   x11  x12  x13  x14  \
# 0  36  27  71   8.1  3.34  11.4  81.5  3243   8.8  42.6  11.7   21   15   59
# 1  35  23  72  11.1  3.14  11.0  78.8  4281   3.5  50.7  14.4    8   10   39
# 2  44  29  74  10.4  3.21   9.8  81.6  4260   0.8  39.4  12.4    6    6   33
# 3  47  45  79   6.5  3.41  11.1  77.5  3125  27.1  50.2  20.6   18    8   24
# 4  43  35  77   7.6  3.44   9.6  84.6  6441  24.4  43.7  14.3   43   38  206
#
#    x15        y
# 0   59   921.87
# 1   57   997.88
# 2   54   962.35
# 3   56   982.29
# 4   55  1071.29

# %%
ColumnName = 'PREC,JANT,JULT,OVR65,POPN,EDUC,HOUS,DENS,NONW,WWDRK,POOR,HC,NOX,SO,HUMID,MORT'
ColumnName = ColumnName.split(',')
print( f'Size of the input vector:{len(ColumnName)-1}')
# Out:
# Size of the input vector:15

# %%
Data.columns = ColumnName
Data.head().T
# Out:
#              0        1        2        3        4
# PREC     36.00    35.00    44.00    47.00    43.00
# JANT     27.00    23.00    29.00    45.00    35.00
# JULT     71.00    72.00    74.00    79.00    77.00
# OVR65     8.10    11.10    10.40     6.50     7.60
# POPN      3.34     3.14     3.21     3.41     3.44
# EDUC     11.40    11.00     9.80    11.10     9.60
# HOUS     81.50    78.80    81.60    77.50    84.60
# DENS   3243.00  4281.00  4260.00  3125.00  6441.00
# NONW      8.80     3.50     0.80    27.10    24.40
# WWDRK    42.60    50.70    39.40    50.20    43.70
# POOR     11.70    14.40    12.40    20.60    14.30
# HC       21.00     8.00     6.00    18.00    43.00
# NOX      15.00    10.00     6.00     8.00    38.00
# SO       59.00    39.00    33.00    24.00   206.00
# HUMID    59.00    57.00    54.00    56.00    55.00
# MORT    921.87   997.88   962.35   982.29  1071.29

# %%
ax =Data.hist(figsize= (10,10),bins = 40)

# %% [markdown]
# ## Homework: <font color='red'> Give a summary by words of the statistical distributions.</font>
# ## Homework: <font color='red'> Justify brifly why a Machine Learning algorithm based on linear projection might not work well with this database. (note that this includes all methods based on dot products).</font>
# ## Homework: <font color='red'> In case this you used linear regression, which preprocessing would you do on the data?.</font>

# %% [markdown]
# ## <font color='green'> Give a summary by words of the statistical distributions.</font><br>
#
# Most variables do not follow a Gaussian distribution and present a high dispersion of values. Some variables, such as NOX and HC, are closer to a normal distribution, although they still contain noticeable outliers. Other variables show skewed distributions and large variability, suggesting that the dataset is heterogeneous and contains non-linear relationships between variables.<br>
#
# ## <font color='green'> Justify brifly why a Machine Learning algorithm based on linear projection might not work well with this database. (note that this includes all methods based on dot products).</font><br>
#
# Machine Learning methods based on linear projections may not work well with this dataset because many variables do not follow Gaussian distributions and contain significant outliers. In addition, several variables may be highly correlated, such as temperature and pollution-related variables, leading to multicollinearity problems. Furthermore, the relationships between pollution, climate, and mortality are likely to be non-linear, which cannot be properly captured by linear models based on dot products.<br>
#
# ## <font color='green'> In case this you used linear regression, which preprocessing would you do on the data?.</font><br>
#
# Before applying linear regression, the data should be normalized or standardized because some variables have very different scales, for example DENS compared to percentage-based variables. It would also be important to analyze correlations between variables, since some of them may provide redundant information (temperatures). Therefore, feature selection or feature engineering techniques could be applied to reduce multicollinearity and improve the quality of the predictors. Additionally, treating outliers could improve the robustness of the model.

# %% [markdown]
# ## Homework: <font color='red'> Print a simple decision tree in order to understand the dependencies of the features on the target database.</font>

# %% [markdown]
# ## <font color='green'> Print a simple decision tree in order to understand the dependencies of the features on the target database.</font>

# %% [markdown]
# ## Helper function for creating a particion of the data base

# %%
Data.columns
# Out:
# Index(['PREC', 'JANT', 'JULT', 'OVR65', 'POPN', 'EDUC', 'HOUS', 'DENS', 'NONW',
#        'WWDRK', 'POOR', 'HC', 'NOX', 'SO', 'HUMID', 'MORT'],
#       dtype='str')

# %%
y = Data['MORT']
X = Data[ColumnName[:-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.25, random_state=0)

# %%
print('Sizes of the databases')
print(f' Size train: {X_train.shape[0]} \n Size validation: {X_valid.shape[0]} \n Size test: {X_test.shape[0]}')
# Out:
# Sizes of the databases
#  Size train: 33
#  Size validation: 12
#  Size test: 15

# %%
from sklearn import tree
from sklearn.tree import export_text
from sklearn.metrics import ( mean_absolute_error, mean_squared_error, r2_score)


clf = tree.DecisionTreeRegressor(max_depth=3, random_state=0)
clf = clf.fit(X_train, y_train)

r = export_text(clf, feature_names=X.columns.to_list())
print(r)

# =========================
# TRAIN EVALUATION
# =========================
y_hat_train = clf.predict(X_train)

mae_train = mean_absolute_error(y_train, y_hat_train)
mse_train = mean_squared_error(y_train, y_hat_train)
rmse_train = np.sqrt(mse_train)
r2_train = r2_score(y_train, y_hat_train)

print("\nTRAIN RESULTS")
print(f"MAE  : {mae_train:.2f}")
print(f"MSE  : {mse_train:.2f}")
print(f"RMSE : {rmse_train:.2f}")
print(f"R²   : {r2_train:.3f}")


# =========================
# TEST EVALUATION
# =========================
y_hat_test = clf.predict(X_test)

mae_test = mean_absolute_error(y_test, y_hat_test)
mse_test = mean_squared_error(y_test, y_hat_test)
rmse_test = np.sqrt(mse_test)
r2_test = r2_score(y_test, y_hat_test)

print("\nTEST RESULTS")
print("-" * 40)
print(f"MAE  : {mae_test:.2f}")
print(f"MSE  : {mse_test:.2f}")
print(f"RMSE : {rmse_test:.2f}")
print(f"R²   : {r2_test:.3f}")

# =========================
# PLOT REAL VS PREDICTED
# =========================
plt.figure(figsize=(8,6))

plt.scatter(y_test, y_hat_test, alpha=0.7)

plt.xlabel("Real MORT")
plt.ylabel("Predicted MORT")

plt.title("Decision Tree Regression:\nReal vs Predicted")

plt.grid(True)

plt.show()
# Out:
# |--- HC <= 7.50
# |   |--- EDUC <= 11.65
# |   |   |--- WWDRK <= 44.40
# |   |   |   |--- value: [913.31]
# |   |   |--- WWDRK >  44.40
# |   |   |   |--- value: [884.88]
# |   |--- EDUC >  11.65
# |   |   |--- POOR <= 14.65
# |   |   |   |--- value: [823.76]
# |   |   |--- POOR >  14.65
# |   |   |   |--- value: [860.10]
# |--- HC >  7.50
# |   |--- NONW <= 27.85
# |   |   |--- EDUC <= 12.00
# |   |   |   |--- value: [964.67]
# |   |   |--- EDUC >  12.00
# |   |   |   |--- value: [917.05]
# |   |--- NONW >  27.85
# |   |   |--- OVR65 <= 7.55
# |   |   |   |--- value: [1113.16]
# |   |   |--- OVR65 >  7.55
# |   |   |   |--- value: [1027.94]
#
#
# TRAIN RESULTS
# MAE  : 15.91
# MSE  : 431.54
# RMSE : 20.77
# R²   : 0.874
#
# TEST RESULTS
# ----------------------------------------
# MAE  : 52.90
# MSE  : 3828.29
# RMSE : 61.87
# R²   : -0.116

# %% [markdown]
# ## Gradient boosting
#
# ### Traing gradient boosting with default parameters
# ### See the effect of overfitting.

# %%
regGradBoost = GradientBoostingRegressor(n_estimators=500, learning_rate=0.1,max_depth=3, subsample = 0.95, loss='squared_error', random_state=0)
regGradBoost.fit(X_train, y_train)
MSE_Test = mean_squared_error(y_test, regGradBoost.predict(X_test))
MSE_Valid = mean_squared_error(y_valid, regGradBoost.predict(X_valid))
MSE_Train = mean_squared_error(y_train, regGradBoost.predict(X_train))
print(' MSE in each databases')
print(f' MSE_Train: {MSE_Train} \n MSE_Valid: {MSE_Valid} \n MSE_Test : {MSE_Test}')
# Out:
#  MSE in each databases
#  MSE_Train: 1.6965869663207569e-15
#  MSE_Valid: 2953.195413121049
#  MSE_Test : 1748.6883995316057

# %%
print(' MSE in each databases')
print(f' MSE_Train: {MSE_Train:2.2f} \n MSE_Valid: {MSE_Valid:2.2f} \n MSE_Test : {MSE_Test:2.2f}')
# Out:
#  MSE in each databases
#  MSE_Train: 0.00
#  MSE_Valid: 2953.20
#  MSE_Test : 1748.69

# %%
data_test = {'y_test': y_test.values, 'y_test_pred' :regGradBoost.predict(X_test)}
DataFrameResults_test = pd.DataFrame(data_test)
DataFrameResults_test.plot(figsize = (3,3))

data_valid = {'y_valid': y_valid.values, 'y_valid_pred' :regGradBoost.predict(X_valid)}
DataFrameResults_valid = pd.DataFrame(data_valid)
DataFrameResults_valid.plot(figsize = (3,3))

data_test = {'y_train': y_train.values, 'y_train_pred' :regGradBoost.predict(X_train)}
DataFrameResults_train = pd.DataFrame(data_test)
DataFrameResults_train.plot(figsize = (3,3))
# Out:
# <Axes: >

# %% [markdown]
# ## Homework: <font color='red'> Explain the origin of the overfitting observed above, and comment why giving the performance on the train database is erroneous.</font>

# %% [markdown]
# ## <font color='green'> Explain the origin of the overfitting observed above, and comment why giving the performance on the train database is erroneous.</font><br>
#
# The overfitting observed is mainly caused by the high complexity of the model, in particular the use of a large number of estimators (500 trees). For a small dataset such as this one, the model has enough capacity to continue reducing the training error until it almost perfectly fits the training data, including noise and non-generalizable patterns. As a result, the model performs extremely well on the training set but fails to generalize properly to unseen data, which leads to a much higher error on the validation and test sets.
# Reporting the performance on the training database alone is misleading because it does not reflect the model’s ability to generalize. A model can achieve almost perfect performance on training data simply by memorizing it, which does not guarantee good performance on new, unseen samples.

# %% [markdown]
# ## Evolution of error with the number of boosting trees

# %%
RMSE_Test,RMSE_Valid,RMSE_Train = list(),list(),list()
for n_estimators in range(10,1000,50):
    regGradBoost = GradientBoostingRegressor(n_estimators=n_estimators, learning_rate=0.1,max_depth=3, random_state=0, loss='squared_error', subsample = 0.95)
    regGradBoost.fit(X_train, y_train)
    RMSE_Test.append(np.sqrt(mean_squared_error(y_test, regGradBoost.predict(X_test))))
    RMSE_Valid.append(np.sqrt(mean_squared_error(y_valid, regGradBoost.predict(X_valid))))
    RMSE_Train.append(np.sqrt(mean_squared_error(y_train, regGradBoost.predict(X_train))))

# %%
index_sliced = list(range(10, 1000, 50))[:len(RMSE_Train)]

df_RMSE_Train = pd.DataFrame(RMSE_Train, index=index_sliced, columns=['RMSE_Train'])
df_RMSE_Valid = pd.DataFrame(RMSE_Valid, index=index_sliced, columns=['RMSE_Valid'])
df_RMSE_Test = pd.DataFrame(RMSE_Test, index=index_sliced, columns=['RMSE_Test'])

# %%
plt.figure(figsize=(5, 5))

# Plot each DataFrame using its index for the x-axis and the RMSE column for the y-axis
plt.plot(df_RMSE_Train.index, df_RMSE_Train['RMSE_Train'], '.-', label='Train')
plt.plot(df_RMSE_Valid.index, df_RMSE_Valid['RMSE_Valid'], '.-', label='Valid')
plt.plot(df_RMSE_Test.index, df_RMSE_Test['RMSE_Test'], '.-', label='Test')

# Set chart titles and axis labels
plt.title('Evolution of the RMSE with the number of trees')
plt.xlabel('Number of trees')
plt.ylabel('RMSE')

# Add a legend to differentiate the Train, Validation, and Test lines
plt.legend()

# Display the plot
plt.show()

# %%
RMSE_Test,RMSE_Valid,RMSE_Train = list(),list(),list()
for max_depth in range(1,15,1):
    regGradBoost = GradientBoostingRegressor(n_estimators=500, learning_rate=0.1,max_depth=max_depth, random_state=0, loss='squared_error', subsample = 0.95)
    regGradBoost.fit(X_train, y_train)
    RMSE_Test.append(np.sqrt(mean_squared_error(y_test, regGradBoost.predict(X_test))))
    RMSE_Valid.append(np.sqrt(mean_squared_error(y_valid, regGradBoost.predict(X_valid))))
    RMSE_Train.append(np.sqrt(mean_squared_error(y_train, regGradBoost.predict(X_train))))

# %%
index_range = list(range(1, 15, 1))

# Create the DataFrames using the new index
df_RMSE_Train = pd.DataFrame(RMSE_Train, index=index_range, columns=['RMSE_Train'])
df_RMSE_Valid = pd.DataFrame(RMSE_Valid, index=index_range, columns=['RMSE_Valid'])
df_RMSE_Test = pd.DataFrame(RMSE_Test, index=index_range, columns=['RMSE_Test'])

# %%
plt.figure(figsize=(5, 5))
plt.plot(df_RMSE_Train.index, df_RMSE_Train['RMSE_Train'], '.-', label='Train')
plt.plot(df_RMSE_Valid.index, df_RMSE_Valid['RMSE_Valid'], '.-', label='Valid')
plt.plot(df_RMSE_Test.index, df_RMSE_Test['RMSE_Test'], '.-', label='Test')
plt.title('Evolution of the RMSE with the Depth of the trees')
plt.xlabel('Depth of the trees')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %% [markdown]
# ## Note the flattening of the curve due to overfitting!!!!!

# %% [markdown]
# # Next we will do cross validation in order to simulate unseen data better

# %% [markdown]
# ## Explanation of Cross validation.
# Taken from https://scikit-learn.org/stable/modules/cross_validation.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y = Data['MORT']
X = Data[ColumnName[:-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# ## Let us use the implementation of cross validation in sklearn.
# ### Note the structure of the score
# ### Note the uncorrelation between test and train and the difference

# %%
def PartitionOfDatabase(Data,Fraction = 0.75):
    NumSamples, NumFeatures = Data.shape
    Index = list(range(NumSamples))
    RandomIndex = np.random.permutation(Index)
    NumTrainElements = int(Fraction*NumSamples)
    TrainIndex = RandomIndex[:NumTrainElements]
    TestIndex = RandomIndex[NumTrainElements:]
    TrainDB = Data.iloc[TrainIndex]
    TestDB = Data.iloc[TestIndex]
    return TrainDB,TestDB

# %%
InputFeatures = [fea for fea in Data.columns if  fea != 'MORT']
print(f' Input variables: \n {InputFeatures}')
# Out:
#  Input variables:
#  ['PREC', 'JANT', 'JULT', 'OVR65', 'POPN', 'EDUC', 'HOUS', 'DENS', 'NONW', 'WWDRK', 'POOR', 'HC', 'NOX', 'SO', 'HUMID']

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# 1. Define the parameter grid to test
param_grid = {
    'n_estimators': [10, 50, 100, 1000, 1500],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [1, 2, 5, 10]
}

# 2. Initialize the base model
gbr = GradientBoostingRegressor(random_state=42)

# 3. Create GridSearchCV with 10-fold cross-validation
# Using negative RMSE as the scoring metric
gbr_cv = GridSearchCV(
    estimator=gbr, 
    param_grid=param_grid, 
    cv=10, 
    scoring='neg_root_mean_squared_error',  # Use negative MSE for scoring
    n_jobs=-1  # Uses all available CPU cores to speed up computation
)

# 4. Prepare fresh training data (Keep your existing database partition logic)
TrainDB_cv, TestDB_cv = PartitionOfDatabase(Data, Fraction=0.75)
TrainDB_cv = TrainDB_cv.astype('float')
TestDB_cv = TestDB_cv.astype('float')
y_train = TrainDB_cv['MORT']
X_train = TrainDB_cv[InputFeatures]
y_test = TestDB_cv['MORT']
X_test = TestDB_cv[InputFeatures]

# 5. Fit the grid search with cross-validation
gbr_cv.fit(X_train, y_train)

# 6. Extract and display the results
best_params = gbr_cv.best_params_
# Convert negative RMSE back to positive RMSE
best_cv_rmse = -gbr_cv.best_score_ 

print("Optimal parameters found by cross-validation:")
print(f"  - n_estimators: {best_params['n_estimators']}")
print(f"  - learning_rate: {best_params['learning_rate']}")
print(f"  - max_depth: {best_params['max_depth']}")
print(f"\nBest Cross-Validation RMSE: {best_cv_rmse:.4f}")

# Optional: Evaluate the best model on your test set
best_model = gbr_cv.best_estimator_
test_predictions = best_model.predict(X_test)
# Out:
# Optimal parameters found by cross-validation:
#   - n_estimators: 50
#   - learning_rate: 0.1
#   - max_depth: 2
#
# Best Cross-Validation RMSE: 42.8019

# %%
# 1. Extract the best model from your grid search
best_reg_gbr = gbr_cv.best_estimator_

# 2. Train Set Predictions & Plot
data_train = {
    'y_train': y_train.values, 
    'y_train_pred': best_reg_gbr.predict(X_train)
}
DataFrameResults_train = pd.DataFrame(data_train)
DataFrameResults_train.plot(figsize=(3, 3))
plt.title('Train Set: Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# 3. Validation Set Predictions & Plot
# (Only runs if you have an explicit X_valid defined in your workspace)
if 'X_valid' in locals() or 'X_valid' in globals():
    data_valid = {
        'y_valid': y_valid.values, 
        'y_valid_pred': best_reg_gbr.predict(X_valid)
    }
    DataFrameResults_valid = pd.DataFrame(data_valid)
    DataFrameResults_valid.plot(figsize=(3, 3))
    plt.title('Validation Set: Actual vs Predicted')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.show()
else:
    print("Skipping Validation Plot: 'X_valid' is not explicitly defined in the workspace.")

# 4. Test Set Predictions & Plot
data_test = {
    'y_test': y_test.values, 
    'y_test_pred': best_reg_gbr.predict(X_test)
}
DataFrameResults_test = pd.DataFrame(data_test)
DataFrameResults_test.plot(figsize=(3, 3))
plt.title('Test Set: Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## Let us see the relative importance of each variable.

# %%
regGradBoost = GradientBoostingRegressor(n_estimators=10, learning_rate=0.1,max_depth=3, random_state=0, loss='squared_error', subsample = 0.95)
regGradBoost.fit(X_train, y_train)
FeatureImportance = pd.DataFrame(regGradBoost.feature_importances_,columns = ['Feature Importance'])
FeatureImportance.index = ColumnName[:-1]
FeatureImportance.sort_values(by = ['Feature Importance'],inplace = True, ascending=False)
FeatureImportance.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Homework: <font color='red'> Give an interpretation of the plausability of the variable ranking (try a sociological explanation).</font>
# ## Homework: <font color='red'> Comment briefly on the difference of ranking with the decision trees.</font>
# ## Homework: <font color='red'> Given the ranking think of feature engineering that might improve the performance.</font>

# %% [markdown]
# # <font color='green'> Give an interpretation of the plausability of the variable ranking (try a sociological explanation).</font><br>
# The ranking obtained by gradient boosting looks very plausible. The variable with more importance is NONW, race at itself is unlinkely to be a cause of mortaility, but it can show as some social determinants, such as health, access to healthcare, income inequality, living conditions, occupational risks, and historical patterns of segregation. It reflects a socialecnomic difference that influences mortality.<br>
# The other variables are much lower, but the order is plausible too, the second most important variable is PREC. This may be associated with geographical and environmental conditions that affect health, such as climate, agricultural conditions, disease prevalence, or air quality patterns. It is important beacuse it shows environmental factors, a big difference form NONW, however it reflects that social and economical situation is more related to mortality than environemntal issues.<br>
# EDUC is also among the most influential variables. This is consistent with many public health studies showing that higher educational attainment is generally associated with healthier lifestyles, better employment opportunities, higher income, and improved access to medical care.<br>
# The relevance of OVR65 is expected because mortality rates naturally depend on the age structure of the population. Areas with a larger elderly population are likely to exhibit higher mortality rates.<br>
# The pollution-related variables (NOX, SO2, and to a lesser extent HC) also appear in the ranking, which is reasonable since air pollution is known to affect respiratory and cardiovascular health. However, their lower importance compared with demographic variables suggests that social and population characteristics explain a larger fraction of the variation in mortality.<br>
# Overall, the ranking suggests that mortality is influenced by a combination of environmental and socioeconomic factors, with demographic and social variables having the strongest predictive power in this dataset.
#
# # <font color='green'> Comment briefly on the difference of ranking with the decision trees.</font><br>
# As expected the rankings are differnt, in the decision tree the most important variable is HC (or at least the one that increases the purity of the bracnhes), wwhich differes really much with the gradient boosting, which has NONW as the most influencial variable with a lot of difference. The following levels of the decision tree are for tha following variables: EDUC, NONW, WWDRK, POOR, and OVR65. In contrast, Gradient Boosting identifies NONW as the most important variable by a large margin, followed by PREC and EDUC, while HC becomes one of the least important variables.<br>
# This difference is expected because a single Decision Tree evaluates variables based on a small number of selected splits, whereas Gradient Boosting combines many trees and measures the overall contribution of each feature across the entire ensemble. As a result, Gradient Boosting generally provides a more stable and reliable estimate of feature importance.
#
# # <font color='green'> Given the ranking think of feature engineering that might improve the performance.</font><br>
# We could comine socialeconomic variables (which as seen are the most important), for example NONW × EDUC, NONW × POOR, or EDUC × POOR, these new features may capture combined social effects that are not completelly represented by the individual variables.<br>
# Second, environmental and climatic variables could be combined into more informative indicators. For example, pollution variables (HC, NOX, and SO2) could be aggregated into a single pollution index. Similarly, climate-related variables such as PREC, HUMID, JANT, and JULT could be used to create composite measures describing overall environmental conditions.<br>
# Third, ratios or normalized features may be useful. For instance, combining POOR and EDUC into a socioeconomic status indicator could provide a more direct representation of the population's living conditions.<br>
# Finally, given the relatively low importance of variables such as JULT, WWDRK, and HC, feature selection could be explored to remove variables that contribute little predictive information. This may reduce noise and improve generalization, especially for simpler models.

# %% [markdown]
#  ### Excercise: <font color='red'> Create an infographic for the work done </font>
#  Use either notebooklm or any chat.
#  Refine the prompt so that the explanation of the work done is clear.

# %% [markdown]
# ### Excercise: <font color='red'> Create an executive report </font>
# Write a short assessment of the work done. Difficulties, challenges, and proposals for a solution.
